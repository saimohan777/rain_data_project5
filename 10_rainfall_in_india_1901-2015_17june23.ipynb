# %% [markdown]
# # 10. rainfall in india 1901-2015 17june23¶
# data analysis from csv file

# %%
import pandas as pd

# %%
data=pd.read_csv("/home/placement/Desktop/saimohan data/csv files/rainfall in india 1901-2015.csv")

# %%
data.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR  \
# count  4116.000000  4112.000000  4113.000000  4110.000000  4112.000000
# mean   1958.218659    18.957320    21.805325    27.359197    43.127432
# std      33.140898    33.585371    35.909488    46.959424    67.831168
# min    1901.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1930.000000     0.600000     0.600000     1.000000     3.000000
# 50%    1958.000000     6.000000     6.700000     7.800000    15.700000
# 75%    1987.000000    22.200000    26.800000    31.300000    49.950000
# max    2015.000000   583.700000   403.500000   605.600000   595.100000
#
#                MAY          JUN          JUL          AUG          SEP  \
# count  4113.000000  4111.000000  4109.000000  4112.000000  4110.000000
# mean     85.745417   230.234444   347.214334   290.263497   197.361922
# std     123.234904   234.710758   269.539667   188.770477   135.408345
# ...

# %%
data
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
data.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# ...

# %%
data.tail(100)
# Out:
#       SUBDIVISION  YEAR   JAN   FEB   MAR   APR    MAY    JUN    JUL    AUG  \
# 4016  LAKSHADWEEP  1915   0.0   0.0  22.9  50.5  143.3  183.4  461.6   76.0
# 4017  LAKSHADWEEP  1916   0.3  13.2  32.0  28.7  130.5  327.6  445.9   31.8
# 4018  LAKSHADWEEP  1917   NaN  68.6   NaN   NaN    NaN    NaN    NaN    NaN
# 4019  LAKSHADWEEP  1919  74.4   1.3  39.4  25.6  249.8  352.1  367.4  175.6
# 4020  LAKSHADWEEP  1920  82.6   NaN  35.6  49.4  203.1  530.0  134.2  116.9
# ...           ...   ...   ...   ...   ...   ...    ...    ...    ...    ...
# 4111  LAKSHADWEEP  2011   5.1   2.8   3.1  85.9  107.2  153.6  350.2  254.0
# 4112  LAKSHADWEEP  2012  19.2   0.1   1.6  76.8   21.2  327.0  231.5  381.2
# 4113  LAKSHADWEEP  2013  26.2  34.4  37.5   5.3   88.3  426.2  296.4  154.4
# 4114  LAKSHADWEEP  2014  53.2  16.1   4.4  14.9   57.4  244.1  116.1  466.1
# 4115  LAKSHADWEEP  2015   2.2   0.5   3.7  87.1  133.1  296.6  257.5  146.4
#
# ...

# %%
#group by subdivision
data.groupby(['SUBDIVISION']).count()
# Out:
#                                     YEAR  JAN  FEB  MAR  APR  MAY  JUN  JUL  \
# SUBDIVISION
# ANDAMAN & NICOBAR ISLANDS            110  110  110  108  108  109  108  108
# ARUNACHAL PRADESH                     97   96   96   95   97   97   96   96
# ASSAM & MEGHALAYA                    115  115  115  115  115  115  115  115
# BIHAR                                115  115  115  115  115  115  115  115
# CHHATTISGARH                         115  115  115  115  115  115  115  115
# COASTAL ANDHRA PRADESH               115  115  115  115  115  115  115  115
# COASTAL KARNATAKA                    115  114  115  115  115  115  115  115
# EAST MADHYA PRADESH                  115  115  115  115  115  115  115  115
# EAST RAJASTHAN                       115  115  115  115  115  115  115  115
# EAST UTTAR PRADESH                   115  115  115  115  115  115  115  115
# GANGETIC WEST BENGAL                 115  115  115  115  115  115  115  115
# ...

# %%
#CHECKING STATEMENT FOR NULL VALUES
data.isna().sum()
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         26
# Jan-Feb         6
# Mar-May         9
# Jun-Sep        10
# Oct-Dec        13
# dtype: int64

# %%
#i want data upto 2010,so we have to locate the data
data1=data.loc[(data.YEAR<=2010)]

# %%
data1
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1   29.2    2.3  528.8
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8   12.2    0.0  446.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0    0.0    1.0  235.1
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7    0.0  202.4  304.5
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0    3.3   26.9  279.5
# ...                         ...   ...   ...    ...    ...    ...    ...
# 4106                LAKSHADWEEP  2006  20.1    0.0   33.0    0.3  327.9
# 4107                LAKSHADWEEP  2007   2.5    4.2    0.2   22.2  166.2
# 4108                LAKSHADWEEP  2008   5.5   19.8  120.7   15.8  180.4
# 4109                LAKSHADWEEP  2009   4.7    1.5    0.1   18.1  162.1
# 4110                LAKSHADWEEP  2010  18.8    0.0    1.2   35.6   79.0
#
#         JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# ...

# %%
data1.tail(10)
# Out:
#       SUBDIVISION  YEAR   JAN   FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 4101  LAKSHADWEEP  2001   4.4  20.4    0.0  104.6  187.3  283.9  198.9  144.3
# 4102  LAKSHADWEEP  2002  10.8  16.8    7.2   23.4  189.8  261.8   81.3  143.9
# 4103  LAKSHADWEEP  2003  11.8  18.2   28.5   18.1  109.6  364.5  400.6   92.1
# 4104  LAKSHADWEEP  2004   7.2   1.5    1.9    7.7  330.2  251.2  280.8  169.5
# 4105  LAKSHADWEEP  2005  17.6  11.1    0.0   37.0   92.8  248.5  378.9  102.4
# 4106  LAKSHADWEEP  2006  20.1   0.0   33.0    0.3  327.9  286.9  172.3  150.7
# 4107  LAKSHADWEEP  2007   2.5   4.2    0.2   22.2  166.2  573.4  427.4  294.7
# 4108  LAKSHADWEEP  2008   5.5  19.8  120.7   15.8  180.4  254.6  363.9  206.6
# 4109  LAKSHADWEEP  2009   4.7   1.5    0.1   18.1  162.1  401.2  266.4  185.0
# 4110  LAKSHADWEEP  2010  18.8   0.0    1.2   35.6   79.0  318.9  336.7  335.1
#
#         SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# ...

# %%
data1=data.drop(['ANNUAL'],axis=1)

# %%
data1
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
data1=data.drop(["Jan-Feb","Mar-May","Jun-Sep","Jun-Sep","Oct-Dec","ANNUAL"],axis=1)
data1
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
data['SUBDIVISION'].unique()
# Out:
# array(['ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH',
#        'ASSAM & MEGHALAYA', 'NAGA MANI MIZO TRIPURA',
#        'SUB HIMALAYAN WEST BENGAL & SIKKIM', 'GANGETIC WEST BENGAL',
#        'ORISSA', 'JHARKHAND', 'BIHAR', 'EAST UTTAR PRADESH',
#        'WEST UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA DELHI & CHANDIGARH',
#        'PUNJAB', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'WEST RAJASTHAN',
#        'EAST RAJASTHAN', 'WEST MADHYA PRADESH', 'EAST MADHYA PRADESH',
#        'GUJARAT REGION', 'SAURASHTRA & KUTCH', 'KONKAN & GOA',
#        'MADHYA MAHARASHTRA', 'MATATHWADA', 'VIDARBHA', 'CHHATTISGARH',
#        'COASTAL ANDHRA PRADESH', 'TELANGANA', 'RAYALSEEMA', 'TAMIL NADU',
#        'COASTAL KARNATAKA', 'NORTH INTERIOR KARNATAKA',
#        'SOUTH INTERIOR KARNATAKA', 'KERALA', 'LAKSHADWEEP'], dtype=object)

# %%
#extracting only for the ARUNACHAL PRADESH
data2=data1.loc[(data1.SUBDIVISION =="ARUNACHAL PRADESH")]

# %%
data2
# Out:
#            SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY     JUN  \
# 110  ARUNACHAL PRADESH  1916  48.1   69.8   71.1  316.1  424.6  1124.9
# 111  ARUNACHAL PRADESH  1917  21.4  164.5    NaN  269.6  107.9   823.8
# 112  ARUNACHAL PRADESH  1918  10.4   11.0  191.2  144.6  861.1  1609.9
# 113  ARUNACHAL PRADESH  1919  34.5   67.8   28.5  256.9  420.6   973.6
# 114  ARUNACHAL PRADESH  1920  14.0  196.3  605.6  364.7  173.6   840.6
# ..                 ...   ...   ...    ...    ...    ...    ...     ...
# 202  ARUNACHAL PRADESH  2011  40.0   51.3  174.5  240.8  219.6   288.4
# 203  ARUNACHAL PRADESH  2012  57.8   35.8  134.2  403.4  187.4   645.8
# 204  ARUNACHAL PRADESH  2013  18.5   40.5  115.1  175.1  335.8   290.0
# 205  ARUNACHAL PRADESH  2014  19.0  101.9   80.3   86.7  299.0   415.8
# 206  ARUNACHAL PRADESH  2015  30.8   47.5   97.5  287.1  238.9   637.9
#
#         JUL    AUG    SEP    OCT   NOV   DEC
# 110     NaN  629.7  333.9    NaN   NaN   NaN
# ...

# %%
data2.isna().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            1
# FEB            1
# MAR            2
# APR            0
# MAY            0
# JUN            1
# JUL            1
# AUG            0
# SEP            0
# OCT            2
# NOV            2
# DEC            2
# dtype: int64

# %% [markdown]
# # how can you add two columns in a data frame

# %%
data1['ANNUAL RAIN']=data1.apply(lambda row: row.JAN + row.FEB + row.MAR + row.APR + row.MAY + row.JUN + row.JUL + row.AUG + row.SEP + row.OCT + row.NOV + row.DEC,axis=1)
#data name should be same 
#data2["ANNUAL YEAR"]=data2.apply(lambda row:row.JAN+row.FEB,axis=1)

# %%
data1
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
data1=data1.drop(['SUBDIVISION'],axis=1)
data1
# Out:
#       YEAR   JAN    FEB   MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0     1901  49.2   87.1  29.2    2.3  528.8  517.5  365.1  481.1  332.6
# 1     1902   0.0  159.8  12.2    0.0  446.1  537.1  228.9  753.7  666.2
# 2     1903  12.7  144.0   0.0    1.0  235.1  479.9  728.4  326.7  339.0
# 3     1904   9.4   14.7   0.0  202.4  304.5  495.1  502.0  160.1  820.4
# 4     1905   1.3    0.0   3.3   26.9  279.5  628.7  368.7  330.5  297.0
# ...    ...   ...    ...   ...    ...    ...    ...    ...    ...    ...
# 4111  2011   5.1    2.8   3.1   85.9  107.2  153.6  350.2  254.0  255.2
# 4112  2012  19.2    0.1   1.6   76.8   21.2  327.0  231.5  381.2  179.8
# 4113  2013  26.2   34.4  37.5    5.3   88.3  426.2  296.4  154.4  180.0
# 4114  2014  53.2   16.1   4.4   14.9   57.4  244.1  116.1  466.1  132.2
# 4115  2015   2.2    0.5   3.7   87.1  133.1  296.6  257.5  146.4  160.4
#
#         OCT    NOV    DEC  ANNUAL RAIN
# 0     388.5  558.2   33.6       3373.2
# ...

# %%
cor_mat=data1.corr()
cor_mat
# Out:
#                  YEAR       JAN       FEB       MAR       APR       MAY  \
# YEAR         1.000000 -0.056235 -0.022144  0.020338  0.008007  0.003594
# JAN         -0.056235  1.000000  0.456183  0.398502  0.209302  0.129622
# FEB         -0.022144  0.456183  1.000000  0.579819  0.367114  0.203062
# MAR          0.020338  0.398502  0.579819  1.000000  0.556856  0.362815
# APR          0.008007  0.209302  0.367114  0.556856  1.000000  0.650595
# MAY          0.003594  0.129622  0.203062  0.362815  0.650595  1.000000
# JUN         -0.013594 -0.033725  0.033703  0.165857  0.457091  0.567618
# JUL         -0.016240 -0.051642  0.016235  0.097334  0.268097  0.332283
# AUG          0.006442  0.011952  0.072159  0.135071  0.256168  0.329499
# SEP         -0.006670  0.024289  0.080148  0.178904  0.382525  0.492378
# OCT          0.002406  0.012374 -0.004581  0.086187  0.368886  0.529342
# NOV         -0.018776  0.067281 -0.023413  0.008814  0.165642  0.351931
# ...

# %%
import seaborn as sns
sns.heatmap(cor_mat,vmax=1,vmin=-1,annot=True,linewidths=.5,cmap='bwr')
# Out:
# <Axes: >

# %%
data
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
#SOUTH WEST MONSOON
data1['SWM']=data1.apply(lambda row:row.JUN + row.JUL + row.AUG + row.SEP,axis=1)

# %%
data1
# Out:
#       YEAR   JAN    FEB   MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0     1901  49.2   87.1  29.2    2.3  528.8  517.5  365.1  481.1  332.6
# 1     1902   0.0  159.8  12.2    0.0  446.1  537.1  228.9  753.7  666.2
# 2     1903  12.7  144.0   0.0    1.0  235.1  479.9  728.4  326.7  339.0
# 3     1904   9.4   14.7   0.0  202.4  304.5  495.1  502.0  160.1  820.4
# 4     1905   1.3    0.0   3.3   26.9  279.5  628.7  368.7  330.5  297.0
# ...    ...   ...    ...   ...    ...    ...    ...    ...    ...    ...
# 4111  2011   5.1    2.8   3.1   85.9  107.2  153.6  350.2  254.0  255.2
# 4112  2012  19.2    0.1   1.6   76.8   21.2  327.0  231.5  381.2  179.8
# 4113  2013  26.2   34.4  37.5    5.3   88.3  426.2  296.4  154.4  180.0
# 4114  2014  53.2   16.1   4.4   14.9   57.4  244.1  116.1  466.1  132.2
# 4115  2015   2.2    0.5   3.7   87.1  133.1  296.6  257.5  146.4  160.4
#
#         OCT    NOV    DEC  ANNUAL RAIN     SWM
# 0     388.5  558.2   33.6       3373.2  1696.3
# ...

# %%
#NORTH WEST MONSOON
data1['NEM']=data1.apply(lambda row:row.OCT + row.NOV + row.DEC,axis=1)

# %%
data1
# Out:
#       YEAR   JAN    FEB   MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0     1901  49.2   87.1  29.2    2.3  528.8  517.5  365.1  481.1  332.6
# 1     1902   0.0  159.8  12.2    0.0  446.1  537.1  228.9  753.7  666.2
# 2     1903  12.7  144.0   0.0    1.0  235.1  479.9  728.4  326.7  339.0
# 3     1904   9.4   14.7   0.0  202.4  304.5  495.1  502.0  160.1  820.4
# 4     1905   1.3    0.0   3.3   26.9  279.5  628.7  368.7  330.5  297.0
# ...    ...   ...    ...   ...    ...    ...    ...    ...    ...    ...
# 4111  2011   5.1    2.8   3.1   85.9  107.2  153.6  350.2  254.0  255.2
# 4112  2012  19.2    0.1   1.6   76.8   21.2  327.0  231.5  381.2  179.8
# 4113  2013  26.2   34.4  37.5    5.3   88.3  426.2  296.4  154.4  180.0
# 4114  2014  53.2   16.1   4.4   14.9   57.4  244.1  116.1  466.1  132.2
# 4115  2015   2.2    0.5   3.7   87.1  133.1  296.6  257.5  146.4  160.4
#
#         OCT    NOV    DEC  ANNUAL RAIN     SWM    NEM
# ...

# %%
cor_mat=data1.corr()
cor_mat
# Out:
#                  YEAR       JAN       FEB       MAR       APR       MAY  \
# YEAR         1.000000 -0.056235 -0.022144  0.020338  0.008007  0.003594
# JAN         -0.056235  1.000000  0.456183  0.398502  0.209302  0.129622
# FEB         -0.022144  0.456183  1.000000  0.579819  0.367114  0.203062
# MAR          0.020338  0.398502  0.579819  1.000000  0.556856  0.362815
# APR          0.008007  0.209302  0.367114  0.556856  1.000000  0.650595
# MAY          0.003594  0.129622  0.203062  0.362815  0.650595  1.000000
# JUN         -0.013594 -0.033725  0.033703  0.165857  0.457091  0.567618
# JUL         -0.016240 -0.051642  0.016235  0.097334  0.268097  0.332283
# AUG          0.006442  0.011952  0.072159  0.135071  0.256168  0.329499
# SEP         -0.006670  0.024289  0.080148  0.178904  0.382525  0.492378
# OCT          0.002406  0.012374 -0.004581  0.086187  0.368886  0.529342
# NOV         -0.018776  0.067281 -0.023413  0.008814  0.165642  0.351931
# ...

# %%
import seaborn as sns
sns.heatmap(cor_mat,vmax=1,vmin=-1,annot=True,linewidths=10,cmap='bwr')
# Out:
# <Axes: >

# %%
data3=data1.drop(["JAN","FEB","MAR","APR","MAY","JUN","AUG","SEP","OCT","NOV","DEC","JUL","YEAR"],axis=1)
data3
# Out:
#       ANNUAL RAIN     SWM    NEM
# 0          3373.2  1696.3  980.3
# 1          3520.7  2185.9  716.7
# 2          2957.4  1874.0  690.6
# 3          3079.6  1977.6  571.0
# 4          2566.7  1624.9  630.8
# ...           ...     ...    ...
# 4111       1533.7  1013.0  316.6
# 4112       1405.5  1119.5  167.1
# 4113       1426.3  1057.0  177.6
# 4114       1395.0   958.5  290.5
# 4115       1642.9   860.9  555.4
#
# [4116 rows x 3 columns]

# %%
cor_mat=data3.corr()
cor_mat
# Out:
#              ANNUAL RAIN       SWM       NEM
# ANNUAL RAIN     1.000000  0.943660  0.529596
# SWM             0.943660  1.000000  0.310432
# NEM             0.529596  0.310432  1.000000

# %%
import seaborn as sns
sns.heatmap(cor_mat,vmax=1,vmin=-1,annot=True,linewidths=10,cmap='bwr')
# Out:
# <Axes: >
